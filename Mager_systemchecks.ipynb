# %% [markdown]
# # This is a Header!

# %% [markdown]
# ## This is a subhead!

# %% [markdown]
# **This is bold text** *This is italicized text*

# %% [markdown]
# ![addy in summer](MaryMPhotography_01.jpg)

# %%
x = 5

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
print("hello world")
# Out:
# hello world

# %%
def addNumbers(a, b):
    result = a+b
    return result
addNumbers(3, 4)
# Out:
# 7
